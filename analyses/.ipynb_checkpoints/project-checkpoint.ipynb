# %%
# %load_ext autoreload
# %autoreload 2

import math
import pandas as pd
import seaborn as sns
import warnings
# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
import numpy as np
import pandas as pd
import matplotlib.transforms as transforms


from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import datetime
import statsmodels

# Local Modules
import sys
import os.path
sys.path.insert(0, os.path.abspath('/scratch/horta/coronawiki/'))
from helpers.load import load_interventions, load_aggregated, load_topics
from helpers.vars import codes, helper_langs, interventions_helper, topics, codes
from helpers.plot import set_size, plot_dates, plot_interventions
from helpers.topics import order_topics, colors_z, get_df_pageviews_topics
from helpers.diffs_n_diffs import get_standard_error_sum
from dateutil.relativedelta import relativedelta
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Latex Configuration
import matplotlib.font_manager as font_manager
from matplotlib.lines import Line2D
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os
# fontpath = os.path.expanduser('~/LinLibertine_DRah.ttf')
# prop = font_manager.FontProperties(fname=fontpath)

params = {
    "axes.titlesize" : 14,
    'axes.labelsize': 12,
    'font.size': 12,
    'legend.fontsize': 12,
    'xtick.labelsize': 13,
    'ytick.labelsize': 13,
#     'font.family': 'Linux Libertine Display',
    'text.usetex': False
}

mpl.rcParams.update(params)

# %%
interventions = load_interventions("../data/interventions.csv")
topics_df, topics = load_topics('../data/topics_linked.csv.xz')
agg = load_aggregated("../data/aggregated_timeseries.json.gz")
codes_order = ["sr", "it", "fr", "en", "nl", "ko", "de", "fi", "ja", "no", "sv", "da"]
time_int = 35

# %%
topics_df.head()
# Out:
#                    index  Geography.Regions.Asia.Central Asia  \
# 0               Rosmalen                                False
# 1           Commelinales                                False
# 2  Transport_in_Honduras                                False
# 3                 QuakeC                                False
# 4           Food_writing                                False
#
#    Geography.Regions.Europe.Eastern Europe  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    History and Society.Military and warfare  Culture.Media.Television  \
# 0                                     False                     False
# 1                                     False                     False
# 2                                     False                     False
# 3                                     False                     False
# 4                                     False                     False
#
#    History and Society.Education  Culture.Media.Books  \
# 0                          False                False
# 1                          False                False
# 2                          False                False
# 3                          False                False
# 4                          False                False
#
#    Geography.Regions.Africa.Africa*  Culture.Visual arts.Architecture  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    Culture.Biography.Women  Geography.Regions.Americas.North America  \
# 0                    False                                     False
# 1                    False                                     False
# 2                    False                                     False
# 3                    False                                     False
# 4                    False                                     False
#
#    STEM.STEM*  Culture.Performing arts  Culture.Literature  \
# 0       False                    False               False
# 1        True                    False               False
# 2        True                    False               False
# 3        True                    False               False
# 4       False                    False                True
#
#    History and Society.Politics and government  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Geography.Regions.Africa.Northern Africa  STEM.Earth and environment  \
# 0                                     False                       False
# 1                                     False                       False
# 2                                     False                       False
# 3                                     False                       False
# 4                                     False                       False
#
#    Geography.Regions.Africa.Central Africa  STEM.Medicine & Health  \
# 0                                    False                   False
# 1                                    False                   False
# 2                                    False                   False
# 3                                    False                   False
# 4                                    False                   False
#
#    STEM.Libraries & Information  Geography.Regions.Europe.Europe*  \
# 0                         False                              True
# 1                         False                             False
# 2                         False                             False
# 3                         False                             False
# 4                         False                             False
#
#    Geography.Regions.Europe.Western Europe  Culture.Media.Radio  STEM.Space  \
# 0                                     True                False       False
# 1                                    False                False       False
# 2                                    False                False       False
# 3                                    False                False       False
# 4                                    False                False       False
#
#    Culture.Visual arts.Comics and Anime  STEM.Technology  \
# 0                                 False            False
# 1                                 False            False
# 2                                 False            False
# 3                                 False             True
# 4                                 False            False
#
#    Culture.Internet culture  Culture.Media.Software  \
# 0                     False                   False
# 1                     False                   False
# 2                     False                   False
# 3                     False                    True
# 4                     False                   False
#
#    Geography.Regions.Asia.East Asia  Geography.Regions.Europe.Southern Europe  \
# 0                             False                                     False
# 1                             False                                     False
# 2                             False                                     False
# 3                             False                                     False
# 4                             False                                     False
#
#    STEM.Biology  Culture.Food and drink  \
# 0         False                   False
# 1          True                   False
# 2         False                   False
# 3         False                   False
# 4         False                    True
#
#    History and Society.Business and economics  Culture.Visual arts.Fashion  \
# 0                                       False                        False
# 1                                       False                        False
# 2                                       False                        False
# 3                                       False                        False
# 4                                       False                        False
#
#    Geography.Regions.Americas.Central America  Geography.Geographical  \
# 0                                       False                   False
# 1                                       False                   False
# 2                                        True                   False
# 3                                       False                   False
# 4                                       False                   False
#
#    Geography.Regions.Oceania  STEM.Physics  Culture.Media.Films  \
# 0                      False         False                False
# 1                      False         False                False
# 2                      False         False                False
# 3                      False         False                False
# 4                      False         False                False
#
#    Geography.Regions.Asia.South Asia  History and Society.Transportation  \
# 0                              False                               False
# 1                              False                               False
# 2                              False                                True
# 3                              False                               False
# 4                              False                               False
#
#    History and Society.History  Geography.Regions.Africa.Western Africa  \
# 0                        False                                    False
# 1                        False                                    False
# 2                        False                                    False
# 3                        False                                    False
# 4                        False                                    False
#
#    Culture.Media.Media*  Geography.Regions.Americas.South America  \
# 0                 False                                     False
# 1                 False                                     False
# 2                 False                                     False
# 3                  True                                     False
# 4                  True                                     False
#
#    Culture.Linguistics  STEM.Computing  Culture.Biography.Biography*  \
# 0                False           False                         False
# 1                False           False                         False
# 2                False           False                         False
# 3                False            True                         False
# 4                False           False                         False
#
#    Culture.Philosophy and religion  Culture.Sports  \
# 0                            False           False
# 1                            False           False
# 2                            False           False
# 3                            False           False
# 4                            False           False
#
#    Geography.Regions.Africa.Southern Africa  Culture.Visual arts.Visual arts*  \
# 0                                     False                             False
# 1                                     False                             False
# 2                                     False                             False
# 3                                     False                             False
# 4                                     False                             False
#
#    Geography.Regions.Africa.Eastern Africa  History and Society.Society  \
# 0                                    False                        False
# 1                                    False                        False
# 2                                    False                        False
# 3                                    False                        False
# 4                                    False                        False
#
#    STEM.Engineering  STEM.Mathematics  Geography.Regions.Asia.West Asia  \
# 0             False             False                             False
# 1             False             False                             False
# 2             False             False                             False
# 3             False             False                             False
# 4             False             False                             False
#
#    STEM.Chemistry  Geography.Regions.Europe.Northern Europe  \
# 0           False                                     False
# 1           False                                     False
# 2           False                                     False
# 3           False                                     False
# 4           False                                     False
#
#    Culture.Media.Video games  Geography.Regions.Asia.Southeast Asia  \
# 0                      False                                  False
# 1                      False                                  False
# 2                      False                                  False
# 3                      False                                  False
# 4                      False                                  False
#
#    Culture.Media.Entertainment  Culture.Media.Music  \
# 0                        False                False
# 1                        False                False
# 2                        False                False
# 3                        False                False
# 4                        False                False
#
#    Geography.Regions.Asia.Asia*  Geography.Regions.Asia.North Asia       qid
# 0                         False                              False  Q2001490
# 1                         False                              False   Q290349
# 2                         False                              False  Q1130638
# 3                         False                              False  Q2122062
# 4                         False                              False  Q5465542

# %%
topics
# Out:
# ['Culture.Biography.Biography*',
#  'Culture.Biography.Women',
#  'Culture.Food and drink',
#  'Culture.Internet culture',
#  'Culture.Linguistics',
#  'Culture.Literature',
#  'Culture.Media.Books',
#  'Culture.Media.Entertainment',
#  'Culture.Media.Films',
#  'Culture.Media.Media*',
#  'Culture.Media.Music',
#  'Culture.Media.Radio',
#  'Culture.Media.Software',
#  'Culture.Media.Television',
#  'Culture.Media.Video games',
#  'Culture.Performing arts',
#  'Culture.Philosophy and religion',
#  'Culture.Sports',
#  'Culture.Visual arts.Architecture',
#  'Culture.Visual arts.Comics and Anime',
#  'Culture.Visual arts.Fashion',
#  'Culture.Visual arts.Visual arts*',
#  'Geography.Geographical',
#  'Geography.Regions.Africa.Africa*',
#  'Geography.Regions.Africa.Central Africa',
#  'Geography.Regions.Africa.Eastern Africa',
#  'Geography.Regions.Africa.Northern Africa',
#  'Geography.Regions.Africa.Southern Africa',
#  'Geography.Regions.Africa.Western Africa',
#  'Geography.Regions.Americas.Central America',
#  'Geography.Regions.Americas.North America',
#  'Geography.Regions.Americas.South America',
#  'Geography.Regions.Asia.Asia*',
#  'Geography.Regions.Asia.Central Asia',
#  'Geography.Regions.Asia.East Asia',
#  'Geography.Regions.Asia.North Asia',
#  'Geography.Regions.Asia.South Asia',
#  'Geography.Regions.Asia.Southeast Asia',
#  'Geography.Regions.Asia.West Asia',
#  'Geography.Regions.Europe.Eastern Europe',
#  'Geography.Regions.Europe.Europe*',
#  'Geography.Regions.Europe.Northern Europe',
#  'Geography.Regions.Europe.Southern Europe',
#  'Geography.Regions.Europe.Western Europe',
#  'Geography.Regions.Oceania',
#  'History and Society.Business and economics',
#  'History and Society.Education',
#  'History and Society.History',
#  'History and Society.Military and warfare',
#  'History and Society.Politics and government',
#  'History and Society.Society',
#  'History and Society.Transportation',
#  'STEM.Biology',
#  'STEM.Chemistry',
#  'STEM.Computing',
#  'STEM.Earth and environment',
#  'STEM.Engineering',
#  'STEM.Libraries & Information',
#  'STEM.Mathematics',
#  'STEM.Medicine & Health',
#  'STEM.Physics',
#  'STEM.STEM*',
#  'STEM.Space',
#  'STEM.Technology']

# %%
interventions
# Out:
# {'fr': {'1st case': Timestamp('2020-01-24 00:00:00'),
#   '1st death': Timestamp('2020-02-14 00:00:00'),
#   'School closure': Timestamp('2020-03-14 00:00:00'),
#   'Public events banned': Timestamp('2020-03-13 00:00:00'),
#   'Lockdown': Timestamp('2020-03-17 00:00:00'),
#   'Mobility': Timestamp('2020-03-16 00:00:00'),
#   'Normalcy': Timestamp('2020-07-02 00:00:00')},
#  'da': {'1st case': Timestamp('2020-02-27 00:00:00'),
#   '1st death': Timestamp('2020-03-12 00:00:00'),
#   'School closure': Timestamp('2020-03-13 00:00:00'),
#   'Public events banned': Timestamp('2020-03-12 00:00:00'),
#   'Lockdown': Timestamp('2020-03-18 00:00:00'),
#   'Mobility': Timestamp('2020-03-11 00:00:00'),
#   'Normalcy': Timestamp('2020-06-05 00:00:00')},
#  'de': {'1st case': Timestamp('2020-01-27 00:00:00'),
#   '1st death': Timestamp('2020-03-09 00:00:00'),
#   'School closure': Timestamp('2020-03-14 00:00:00'),
#   'Public events banned': Timestamp('2020-03-22 00:00:00'),
#   'Lockdown': Timestamp('2020-03-22 00:00:00'),
#   'Mobility': Timestamp('2020-03-16 00:00:00'),
#   'Normalcy': Timestamp('2020-07-10 00:00:00')},
#  'it': {'1st case': Timestamp('2020-01-31 00:00:00'),
#   '1st death': Timestamp('2020-02-22 00:00:00'),
#   'School closure': Timestamp('2020-03-05 00:00:00'),
#   'Public events banned': Timestamp('2020-03-09 00:00:00'),
#   'Lockdown': Timestamp('2020-03-11 00:00:00'),
#   'Mobility': Timestamp('2020-03-11 00:00:00'),
#   'Normalcy': Timestamp('2020-06-26 00:00:00')},
#  'nl': {'1st case': Timestamp('2020-02-27 00:00:00'),
#   '1st death': Timestamp('2020-03-06 00:00:00'),
#   'School closure': Timestamp('2020-03-11 00:00:00'),
#   'Public events banned': Timestamp('2020-03-24 00:00:00'),
#   'Mobility': Timestamp('2020-03-16 00:00:00'),
#   'Normalcy': Timestamp('2020-05-29 00:00:00')},
#  'no': {'1st case': Timestamp('2020-02-26 00:00:00'),
#   '1st death': Timestamp('2020-02-26 00:00:00'),
#   'School closure': Timestamp('2020-03-13 00:00:00'),
#   'Public events banned': Timestamp('2020-03-12 00:00:00'),
#   'Lockdown': Timestamp('2020-03-24 00:00:00'),
#   'Mobility': Timestamp('2020-03-11 00:00:00'),
#   'Normalcy': Timestamp('2020-06-04 00:00:00')},
#  'sr': {'1st case': Timestamp('2020-03-06 00:00:00'),
#   '1st death': Timestamp('2020-03-20 00:00:00'),
#   'School closure': Timestamp('2020-03-15 00:00:00'),
#   'Public events banned': Timestamp('2020-03-21 00:00:00'),
#   'Lockdown': Timestamp('2020-03-21 00:00:00'),
#   'Mobility': Timestamp('2020-03-16 00:00:00'),
#   'Normalcy': Timestamp('2020-05-02 00:00:00')},
#  'sv': {'1st case': Timestamp('2020-01-31 00:00:00'),
#   '1st death': Timestamp('2020-03-11 00:00:00'),
#   'School closure': Timestamp('2020-03-18 00:00:00'),
#   'Public events banned': Timestamp('2020-03-12 00:00:00'),
#   'Mobility': Timestamp('2020-03-11 00:00:00'),
#   'Normalcy': Timestamp('2020-06-05 00:00:00')},
#  'ko': {'1st case': Timestamp('2020-01-20 00:00:00'),
#   '1st death': Timestamp('2020-02-20 00:00:00'),
#   'School closure': Timestamp('2020-02-23 00:00:00'),
#   'Mobility': Timestamp('2020-02-25 00:00:00'),
#   'Normalcy': Timestamp('2020-04-15 00:00:00')},
#  'ca': {'1st case': Timestamp('2020-01-31 00:00:00'),
#   '1st death': Timestamp('2020-02-13 00:00:00'),
#   'School closure': Timestamp('2020-03-12 00:00:00'),
#   'Public events banned': Timestamp('2020-03-08 00:00:00'),
#   'Lockdown': Timestamp('2020-03-14 00:00:00'),
#   'Mobility': Timestamp('2020-03-16 00:00:00')},
#  'fi': {'1st case': Timestamp('2020-01-29 00:00:00'),
#   '1st death': Timestamp('2020-03-21 00:00:00'),
#   'School closure': Timestamp('2020-03-16 00:00:00'),
#   'Public events banned': Timestamp('2020-03-16 00:00:00'),
#   'Mobility': Timestamp('2020-03-16 00:00:00'),
#   'Normalcy': Timestamp('2020-05-21 00:00:00')},
#  'ja': {'1st case': Timestamp('2020-01-16 00:00:00'),
#   '1st death': Timestamp('2020-02-13 00:00:00'),
#   'School closure': Timestamp('2020-02-27 00:00:00'),
#   'Public events banned': Timestamp('2020-02-25 00:00:00'),
#   'Mobility': Timestamp('2020-03-31 00:00:00'),
#   'Normalcy': Timestamp('2020-06-14 00:00:00')},
#  'en': {'Mobility': Timestamp('2020-03-16 00:00:00'),
#   'Normalcy': Timestamp('2020-05-21 00:00:00')}}

# %%
df = pd.DataFrame.from_dict(agg)
df.head()
# Out:
#                                                      ja.m  \
# len                                               1197788
# sum     2018-01-01    22328288
# 2018-01-02    22278953
# ...
# covid   {'len': 30, 'sum': [55, 55, 51, 46, 70, 77, 73...
# topics  {'Culture.Biography.Biography*': {'len': 14904...
#
#                                                        it  \
# len                                               1594039
# sum     2018-01-01     3338750
# 2018-01-02     5428428
# ...
# covid   {'len': 33, 'sum': [50, 103, 130, 112, 119, 75...
# topics  {'Culture.Biography.Biography*': {'len': 29427...
#
#                                                      da.m  \
# len                                                256451
# sum     2018-01-01    765123
# 2018-01-02    443384
# 2018...
# covid   {'len': 4, 'sum': [0, 2, 1, 0, 0, 2, 0, 1, 5, ...
# topics  {'Culture.Biography.Biography*': {'len': 57720...
#
#                                                        tr  \
# len                                                346007
# sum     2018-01-01     407629
# 2018-01-02     426791
# 20...
# covid   {'len': 64, 'sum': [1, 3, 6, 1, 0, 4, 1, 13, 6...
# topics  {'Culture.Biography.Biography*': {'len': 70443...
#
#                                                      no.m  \
# len                                                516838
# sum     2018-01-01     715031
# 2018-01-02     536506
# 20...
# covid   {'len': 10, 'sum': [7, 5, 2, 2, 2, 0, 3, 2, 7,...
# topics  {'Culture.Biography.Biography*': {'len': 11603...
#
#                                                        en  \
# len                                               6047509
# sum     2018-01-01     86763830
# 2018-01-02    11224534...
# covid   {'len': 306, 'sum': [575, 1081, 1265, 1167, 10...
# topics  {'Culture.Biography.Biography*': {'len': 14038...
#
#                                                        sr  \
# len                                                632128
# sum     2018-01-01    192409
# 2018-01-02    253653
# 2018...
# covid   {'len': 9, 'sum': [6, 13, 11, 6, 13, 6, 11, 9,...
# topics  {'Culture.Biography.Biography*': {'len': 37718...
#
#                                                      tr.m  \
# len                                                345790
# sum     2018-01-01     493684
# 2018-01-02     483443
# 20...
# covid   {'len': 64, 'sum': [3, 2, 2, 9, 2, 2, 1, 4, 6,...
# topics  {'Culture.Biography.Biography*': {'len': 70434...
#
#                                                      en.m  \
# len                                               6045654
# sum     2018-01-01    135822131
# 2018-01-02    12708735...
# covid   {'len': 306, 'sum': [911, 1006, 919, 1026, 978...
# topics  {'Culture.Biography.Biography*': {'len': 14038...
#
#                                                        no  \
# len                                                531478
# sum     2018-01-01     224417
# 2018-01-02     374771
# 20...
# covid   {'len': 10, 'sum': [2, 4, 3, 1, 4, 0, 1, 5, 5,...
# topics  {'Culture.Biography.Biography*': {'len': 11804...
#
#                                                        sv  \
# len                                               3735720
# sum     2018-01-01          0
# 2018-01-02          0
# 20...
# covid   {'len': 8, 'sum': [0, 0, 0, 0, 0, 0, 0, 0, 0, ...
# topics  {'Culture.Biography.Biography*': {'len': 14706...
#
#                                                      nl.m  \
# len                                               1621578
# sum     2018-01-01    3331046
# 2018-01-02    2494738
# 20...
# covid   {'len': 32, 'sum': [19, 18, 16, 14, 15, 18, 10...
# topics  {'Culture.Biography.Biography*': {'len': 15284...
#
#                                                        nl  \
# len                                               2003807
# sum     2018-01-01    1199379
# 2018-01-02    1926749
# 20...
# covid   {'len': 32, 'sum': [12, 20, 17, 15, 11, 14, 16...
# topics  {'Culture.Biography.Biography*': {'len': 15294...
#
#                                                        da  \
# len                                                258063
# sum     2018-01-01    206514
# 2018-01-02    322681
# 2018...
# covid   {'len': 4, 'sum': [1, 1, 4, 0, 0, 4, 1, 3, 1, ...
# topics  {'Culture.Biography.Biography*': {'len': 58323...
#
#                                                        de  \
# len                                               2415136
# sum     2018-01-01     9287425
# 2018-01-02    14474378
# ...
# covid   {'len': 77, 'sum': [160, 209, 219, 216, 334, 1...
# topics  {'Culture.Biography.Biography*': {'len': 36668...
#
#                                                      fr.m  \
# len                                               2188967
# sum     2018-01-01    13167585
# 2018-01-02    12184735
# ...
# covid   {'len': 16, 'sum': [116, 105, 98, 104, 114, 10...
# topics  {'Culture.Biography.Biography*': {'len': 38254...
#
#                                                      ca.m  \
# len                                                610575
# sum     2018-01-01    169499
# 2018-01-02    149404
# 2018...
# covid   {'len': 49, 'sum': [3, 2, 4, 1, 10, 1, 3, 5, 5...
# topics  {'Culture.Biography.Biography*': {'len': 99190...
#
#                                                      de.m  \
# len                                               2407385
# sum     2018-01-01    20345709
# 2018-01-02    15585298
# ...
# covid   {'len': 77, 'sum': [233, 189, 142, 226, 220, 2...
# topics  {'Culture.Biography.Biography*': {'len': 36663...
#
#                                                      ko.m  \
# len                                                489181
# sum     2018-01-01    1484496
# 2018-01-02    1248031
# 20...
# covid   {'len': 113, 'sum': [6, 5, 8, 8, 10, 2, 7, 7, ...
# topics  {'Culture.Biography.Biography*': {'len': 75406...
#
#                                                      fi.m  \
# len                                                480638
# sum     2018-01-01    1319053
# 2018-01-02    1094280
# 20...
# covid   {'len': 9, 'sum': [0, 0, 8, 0, 0, 2, 0, 3, 1, ...
# topics  {'Culture.Biography.Biography*': {'len': 10422...
#
#                                                      sr.m  \
# len                                                396063
# sum     2018-01-01     451383
# 2018-01-02     462824
# 20...
# covid   {'len': 9, 'sum': [11, 20, 15, 30, 33, 17, 31,...
# topics  {'Culture.Biography.Biography*': {'len': 37580...
#
#                                                        ja  \
# len                                               1197856
# sum     2018-01-01     7828155
# 2018-01-02     8759385
# ...
# covid   {'len': 30, 'sum': [26, 42, 53, 114, 134, 54, ...
# topics  {'Culture.Biography.Biography*': {'len': 14904...
#
#                                                        fr  \
# len                                               2195949
# sum     2018-01-01     6441009
# 2018-01-02     9079323
# ...
# covid   {'len': 16, 'sum': [62, 91, 109, 107, 113, 81,...
# topics  {'Culture.Biography.Biography*': {'len': 38258...
#
#                                                        fi  \
# len                                                481854
# sum     2018-01-01     523135
# 2018-01-02     648344
# 20...
# covid   {'len': 9, 'sum': [2, 2, 2, 3, 0, 3, 2, 0, 2, ...
# topics  {'Culture.Biography.Biography*': {'len': 10444...
#
#                                                        ca  \
# len                                                642031
# sum     2018-01-01     111910
# 2018-01-02     198405
# 20...
# covid   {'len': 49, 'sum': [6, 6, 9, 10, 4, 7, 15, 13,...
# topics  {'Culture.Biography.Biography*': {'len': 10175...
#
#                                                      it.m  \
# len                                               1588312
# sum     2018-01-01    12856884
# 2018-01-02    12887390
# ...
# covid   {'len': 33, 'sum': [139, 187, 162, 180, 127, 1...
# topics  {'Culture.Biography.Biography*': {'len': 29422...
#
#                                                      sv.m  \
# len                                               1959446
# sum     2018-01-01    2383474
# 2018-01-02    1873096
# 20...
# covid   {'len': 8, 'sum': [19, 12, 13, 14, 11, 15, 12,...
# topics  {'Culture.Biography.Biography*': {'len': 14668...
#
#                                                        ko
# len                                                490314
# sum     2018-01-01     819174
# 2018-01-02     959239
# 20...
# covid   {'len': 113, 'sum': [3, 20, 20, 16, 20, 8, 1, ...
# topics  {'Culture.Biography.Biography*': {'len': 75498...

# %%
import matplotlib.dates as mdates
italy = agg['it.m']['sum']
# italy = italy[(italy.index.year == 2020) & (italy.index.month <= 12) & (italy.index.month >= 1)]
fig = plt.figure(constrained_layout=False, figsize=(28,10))
